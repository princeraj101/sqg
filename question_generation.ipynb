# %%
# !pip install -U transformers==3.0.0

# %%
# !python -m nltk.downloader punkt
# Out:
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !git clone https://github.com/patil-suraj/question_generation.git
# Out:
# Cloning into 'question_generation'...
# remote: Enumerating objects: 265, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 265 (delta 100), reused 95 (delta 95), pack-reused 156
# Receiving objects: 100% (265/265), 289.06 KiB | 8.50 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# %cd question_generation
# Out:
# /content/question_generation

# %%
# !pip install nlp
# !python3 prepare_data.py --task e2e_qg --valid_for_qg_only --model_type t5 --dataset_path data/squad_multitask/ --qg_format highlight_qg_format --max_source_length 512 --max_target_length 32 --train_file_name train_data_e2e_qg_t5.pt --valid_file_name valid_data_e2e_qg_t5.pt \
# Out:
# ...
# python3: can't open file 'prepare_data.py': [Errno 2] No such file or directory

# %%
from run_qg import run_qg

args_dict = {
    "model_name_or_path": "t5-small",
    "model_type": "t5",
    "tokenizer_name_or_path": "t5_qg_tokenizer",
    "output_dir": "t5-small-qg-hl",
    "train_file_path": "data/train_data_e2e_qg_t5.pt",
    "valid_file_path": "data/valid_data_e2e_qg_t5.pt",
    "per_device_train_batch_size": 32,
    "per_device_eval_batch_size": 32,
    "gradient_accumulation_steps": 8,
    "learning_rate": 1e-4,
    "num_train_epochs": 5,
    "seed": 42,
    "do_train": True,
    "do_eval": True,
    "evaluate_during_training": True,
    "logging_steps": 100
}

# start training
run_qg(args_dict)
# Out:
# 11/25/2021 15:33:05 - INFO - transformers.training_args -   PyTorch: setting up devices
# 11/25/2021 15:33:05 - WARNING - run_qg -   Process rank: -1, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# ...

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python3 eval.py --model_name_or_path t5-small-qg-hl --valid_file_path data/valid_data_e2e_qg_t5.pt --model_type t5 --num_beams 4 --max_decoding_length 32 --output_path hypothesis_file.txt
# Out:
#   0% 0/65 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# 100% 65/65 [02:20<00:00,  2.17s/it]
